# %%
weather_data=api.get("Weather_data")
weather_contion=api.get("Weather Poluttion")
df=pd.reda_csv9("car accciend ")

# %% [markdown]
# 1. I will merge weather_data and weather_contion with df
# 2. I will write data to database

# %%
import seaborn as sns

df = sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
from dotenv import load_dotenv
import os
load_dotenv(".env")
# Out:
# True

# %%
MYSQL_USER=os.getenv('MYSQL_USER')
MYSQL_PASSWORD=os.getenv('MYSQL_PASSWORD')
MYSQL_DATABASE=os.getenv('MYSQL_DATABASE')

# %%
from sqlalchemy import create_engine
DATABASE_URL = (
    f"mysql+pymysql://{os.getenv('MYSQL_USER')}:{os.getenv('MYSQL_PASSWORD')}"
    f"@172.20.0.2:3306/{os.getenv('MYSQL_DATABASE')}"
)

engine = create_engine(DATABASE_URL, echo=False)

# %%
engine
# Out:
# Engine(mysql+pymysql://MYSQL_USER:***@172.20.0.2:3306/MYSQL_DATABASE)

# %%
df.to_sql("titantic", con=engine, if_exists="replace", index=False )
# Out:
# 2026-06-14 17:49:40,615 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2026-06-14 17:49:40,615 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-14 17:49:40,617 INFO sqlalchemy.engine.Engine SELECT @@sql_mode
# 2026-06-14 17:49:40,618 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-14 17:49:40,619 INFO sqlalchemy.engine.Engine SELECT @@lower_case_table_names
# 2026-06-14 17:49:40,620 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-14 17:49:40,622 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-14 17:49:40,625 INFO sqlalchemy.engine.Engine DESCRIBE `MYSQL_DATABASE`.`titantic`
# 2026-06-14 17:49:40,626 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-14 17:49:40,635 INFO sqlalchemy.engine.Engine
# CREATE TABLE titantic (
# 	survived BIGINT,
# 	pclass BIGINT,
# 	sex TEXT,
# 	age FLOAT(53),
# 	sibsp BIGINT,
# 	parch BIGINT,
# 	fare FLOAT(53),
# 	embarked TEXT,
# 	class TEXT,
# 	who TEXT,
# 	adult_male BOOL,
# 	deck TEXT,
# 	embark_town TEXT,
# 	alive TEXT,
# ...

# %%
import pandas as pd

# %%
my_df=pd.read_sql("Select *  from titantic", con=engine)
# Out:
# 2026-06-14 17:54:12,224 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2026-06-14 17:54:12,226 INFO sqlalchemy.engine.Engine DESCRIBE `MYSQL_DATABASE`.`Select *  from titantic`
# 2026-06-14 17:54:12,230 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-14 17:54:12,236 INFO sqlalchemy.engine.Engine Select *  from titantic
# 2026-06-14 17:54:12,239 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2026-06-14 17:54:12,270 INFO sqlalchemy.engine.Engine ROLLBACK

# %%
my_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man           1  NaN  Southampton    no      0
# 1  woman           0    C    Cherbourg   yes      0
# 2  woman           0  NaN  Southampton   yes      1
# 3  woman           0    C  Southampton   yes      0
# 4    man           1  NaN  Southampton    no      1
